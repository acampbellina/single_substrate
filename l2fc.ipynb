# %%
import pandas as pd
import pandas.rpy.common as com
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import brewer2mpl
from mpltools import style
from IPython.display import FileLink
import seaborn as sns
style.use("ggplot")
# %matplotlib inline
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pytz/__init__.py:29: UserWarning: Module argparse was already imported from /opt/anaconda/lib/python2.7/argparse.pyc, but /opt/anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# ###This is the file from the [Sparsity Notebook](./Sparsity_make_l2fc_table.ipynb).

# %%
df_all = pd.read_csv("data/l2fc_table.csv")

# %%
print(df_all)
# Out:
#       sparsity_threshold  Day Treatment       OTU  log2FoldChange         p  \
# 0                   0.55   30    13CCSS   OTU.783       -0.337083  0.996574
# 1                   0.55   30    13CCSS    OTU.79        0.759818  0.488986
# 2                   0.55   30    13CCSS   OTU.304        0.418365  0.808984
# 3                   0.55   30    13CCSS    OTU.50        0.728969  0.525237
# 4                   0.55   30    13CCSS   OTU.382        2.983357  0.000000
# 5                   0.55   30    13CCSS   OTU.465        0.551599  0.688754
# 6                   0.55   30    13CCSS   OTU.162        0.211671  0.920419
# 7                   0.55   30    13CCSS  OTU.1084        1.189434  0.136626
# 8                   0.55   30    13CCSS   OTU.525        1.902067  0.002101
# 9                   0.55   30    13CCSS   OTU.985        1.194349  0.135894
# 10                  0.55   30    13CCSS   OTU.587       -0.146184  0.986588
# 11                  0.55   30    13CCSS   OTU.342       -0.026989  0.973079
# 12                  0.55   30    13CCSS    OTU.12        0.393081  0.882631
# 13                  0.55   30    13CCSS   OTU.122       -0.232489  0.994183
# 14                  0.55   30    13CCSS   OTU.141       -0.128569  0.986343
# 15                  0.55   30    13CCSS   OTU.121        1.338225  0.057974
# 16                  0.55   30    13CCSS   OTU.599        0.926130  0.327127
# 17                  0.55   30    13CCSS   OTU.171        1.548884  0.023937
# 18                  0.55   30    13CCSS   OTU.440        0.415172  0.797459
# 19                  0.55   30    13CCSS  OTU.1408        0.173935  0.924710
# 20                  0.55   30    13CCSS   OTU.155        0.553031  0.713635
# 21                  0.55   30    13CCSS   OTU.113        1.665233  0.011341
# 22                  0.55   30    13CCSS   OTU.978        1.275382  0.089550
# 23                  0.55   30    13CCSS   OTU.153        0.349888  0.862064
# 24                  0.55   30    13CCSS    OTU.80        0.552428  0.705979
# 25                  0.55   30    13CCSS   OTU.106        0.380916  0.838101
# 26                  0.55   30    13CCSS    OTU.69       -0.012325  0.974966
# 27                  0.55   30    13CCSS   OTU.376       -0.101279  0.979097
# 28                  0.55   30    13CCSS   OTU.277        1.052090  0.224182
# 29                  0.55   30    13CCSS   OTU.360        0.405013  0.814882
# ...                  ...  ...       ...       ...             ...       ...
# 1168                0.55   30    13CCPS   OTU.166       -0.126662  0.991174
# 1169                0.55   30    13CCPS   OTU.161       -0.128079  0.990617
# 1170                0.55   30    13CCPS   OTU.775       -0.463616  0.999168
# 1171                0.55   30    13CCPS   OTU.188       -0.364297  0.999715
# 1172                0.55   30    13CCPS   OTU.877       -0.151233  0.992689
OTU_series = df_all.groupby("OTU").first()["Rank2"]
df_pivot = df_pivot.join(OTU_series)

phyla = df_all.sort("log2FoldChange").groupby("Rank2").last()
phyla.sort("log2FoldChange", ascending=False, inplace=True)

xd = dict([(p, x + 1) for x, p in enumerate(phyla.index.tolist())])
xmax = np.max(xd.values()) + 1
X = []
for p in df_pivot.Rank2:
    try:
        X.append(xd[p])
    except KeyError:
        X.append(xmax)
df_pivot["X"] = X

m1 = brewer2mpl.get_map("Paired", "qualitative", 8)
m2 = brewer2mpl.get_map("Dark2", "qualitative", 8)
colors = m1.hex_colors + m2.hex_colors
cd = dict(zip(phyla.index.tolist(), colors))
phylum_color = []
for p in df_pivot.Rank2:
    try:
        phylum_color.append(cd[p])
    except KeyError:
        phylum_color.append("#151515")
df_pivot["phylum_color"] = phylum_color
df_pivot
# Out:
# /opt/anaconda/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'cols' keyword is deprecated, use 'columns' instead
#   warnings.warn(msg, FutureWarning)
# /opt/anaconda/lib/python2.7/site-packages/pandas/util/decorators.py:81: FutureWarning: the 'rows' keyword is deprecated, use 'index' instead
#   warnings.warn(msg, FutureWarning)
#           (13CCPS, 30)  (13CCSS, 30)                   Rank2   X phylum_color
# OTU
# OTU.1        -1.330105     -0.985248          Actinobacteria  10      #D95F02
# OTU.10       -0.802412     -0.911840          Proteobacteria   2      #1F78B4
# OTU.100       1.471091      1.503862          Proteobacteria   2      #1F78B4
# OTU.1001     -0.078289           NaN          Planctomycetes   5      #FB9A99
# OTU.1005      0.125570      0.287432             Chloroflexi   4      #33A02C
# OTU.1006           NaN      0.045910          Planctomycetes   5      #FB9A99
# OTU.101      -0.099885     -0.464152          Proteobacteria   2      #1F78B4
# OTU.1010           NaN      0.372830          Proteobacteria   2      #1F78B4
# OTU.1016      0.004130      0.161503          Proteobacteria   2      #1F78B4
# OTU.102       0.041715     -0.691802         Verrucomicrobia   1      #A6CEE3
# OTU.1021      0.608670           NaN          Proteobacteria   2      #1F78B4
# OTU.1023      2.004803           NaN         Verrucomicrobia   1      #A6CEE3
# OTU.1028     -0.438937           NaN          Proteobacteria   2      #1F78B4
# OTU.1029           NaN     -0.026366          Proteobacteria   2      #1F78B4
# OTU.103       0.453609      1.149099          Proteobacteria   2      #1F78B4
# OTU.1031           NaN     -0.129452          Proteobacteria   2      #1F78B4
# OTU.1034           NaN      1.300053          Proteobacteria   2      #1F78B4
# OTU.1035     -0.410341     -0.073197          Proteobacteria   2      #1F78B4
# OTU.104      -0.484668      0.032228          Actinobacteria  10      #D95F02
# OTU.1043           NaN     -0.025153          Actinobacteria  10      #D95F02
# OTU.1045           NaN     -1.572948          Proteobacteria   2      #1F78B4
# OTU.105      -0.865530     -0.485647          Proteobacteria   2      #1F78B4
# OTU.1052      1.168697           NaN             Chloroflexi   4      #33A02C
# OTU.1053     -0.354197     -0.191865          Proteobacteria   2      #1F78B4
# OTU.1056     -0.188625     -0.901156           Acidobacteria   6      #E31A1C
# OTU.106            NaN      0.380916           Bacteroidetes   3      #B2DF8A
# OTU.1062      1.005251           NaN          Planctomycetes   5      #FB9A99
# OTU.1063           NaN      1.703756           Acidobacteria   6      #E31A1C
# OTU.1068           NaN      0.446227          Planctomycetes   5      #FB9A99
# OTU.107       0.372003           NaN           Bacteroidetes   3      #B2DF8A
# ...                ...           ...                     ...  ..          ...
# OTU.900       0.502885           NaN          Proteobacteria   2      #1F78B4
# OTU.901            NaN      0.293161          Proteobacteria   2      #1F78B4
# OTU.904            NaN     -0.024799  Candidate_division_WS3  16      #666666
# OTU.906            NaN      0.379635          Planctomycetes   5      #FB9A99
# OTU.915            NaN      0.994341          Planctomycetes   5      #FB9A99
# OTU.918       0.544847      0.162398          Proteobacteria   2      #1F78B4
# OTU.92        1.052552      0.472916          Proteobacteria   2      #1F78B4
# OTU.920       0.896963           NaN          Planctomycetes   5      #FB9A99
# OTU.932            NaN      0.040460          Planctomycetes   5      #FB9A99
# OTU.933            NaN     -0.191170          Proteobacteria   2      #1F78B4
# OTU.94       -0.421619      0.100160           Acidobacteria   6      #E31A1C
# OTU.943            NaN      0.862486          Proteobacteria   2      #1F78B4
# OTU.945            NaN      1.713175            Spirochaetes   9      #1B9E77
# OTU.947            NaN      0.257887          Proteobacteria   2      #1F78B4
# OTU.948            NaN      1.766810         Verrucomicrobia   1      #A6CEE3
# OTU.95             NaN     -0.703060           Bacteroidetes   3      #B2DF8A
# OTU.96       -0.792171      0.593558          Proteobacteria   2      #1F78B4
# OTU.960            NaN      1.318714             Chloroflexi   4      #33A02C
# OTU.963       0.410728           NaN           Bacteroidetes   3      #B2DF8A
# OTU.967            NaN     -0.464935          Proteobacteria   2      #1F78B4
# OTU.968       1.102655      0.888421             Chloroflexi   4      #33A02C
# OTU.97       -0.452142      0.301159           Acidobacteria   6      #E31A1C
# OTU.978       0.753283      1.275382           Bacteroidetes   3      #B2DF8A
# OTU.98        2.322171      2.558323             Chloroflexi   4      #33A02C
# OTU.981            NaN     -0.038694          Proteobacteria   2      #1F78B4
# OTU.982       1.096199           NaN          Proteobacteria   2      #1F78B4
# OTU.984       0.025258     -0.369353          Proteobacteria   2      #1F78B4
# OTU.985            NaN      1.194349           Bacteroidetes   3      #B2DF8A
# OTU.99       -0.400385           NaN           Bacteroidetes   3      #B2DF8A
# OTU.991            NaN     -0.193906             Chloroflexi   4      #33A02C
#
# [795 rows x 5 columns]

# %%
df = df_pivot

matplotlib.rcParams["axes.facecolor"] = "white"
matplotlib.rcParams["axes.edgecolor"] = "#151515"
matplotlib.rcParams["grid.color"] = "#F5F5F5"
matplotlib.rcParams["grid.alpha"] = "0.75"

thresh = 0.75

fig = plt.figure()
fig.set_size_inches(12,7)

gs = gridspec.GridSpec(nrows = 2, ncols = 3, width_ratios=[0.3,0.15,0.3], 
                       left=0.05, right=0.95, bottom=0.05, top=0.95,
                       hspace=0.3, wspace=0.12)

N = len(phyla.index) + 1
treatment = ["13CCPS", "13CCSS"]
days = [30]
ncol = 2
nrow = 1

for j, t in zip(range(ncol), treatment):
    for i, d in zip(range(nrow), days):
        try:
            ax = fig.add_subplot(gs[j, i])
            points = ax.scatter(df.X + 0.45 * np.random.random(len(df.X)),
                                df[(t,d)], alpha = 0.75, c = df.phylum_color.tolist(), 
                                s = 20, linewidth=0.25, edgecolor = "#505050")
            ax.axhline(thresh, color = "#151515")
            ax.set_title("%s, Day %s"%(t, d))
        except KeyError:
            ax.set_visible(False)
            continue
            
axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max() 

for axi in axs:
    axi.set_xlim([xmin,xmax])
    
axHistX = fig.add_subplot(gs[0, 1])
axHistX.hist(df_all[df_all["Treatment"]=="13CCPS"]["log2FoldChange"].values, orientation="horizontal", 
             bins=25, fc = "#252525")
axHistX.axhline(thresh)
axHistX.set_yticklabels([])
axHistX.set_ylim([-3,4])

axHistY = fig.add_subplot(gs[1, 1])
axHistY.hist(df_all[df_all["Treatment"]=="13CCSS"]["log2FoldChange"].values, orientation="horizontal", 
             bins=25, fc = "#252525")
axHistY.axhline(thresh)

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()
ymin = np.array([axi.get_ylim()[0] for axi in axs]).min()
ymax = np.array([axi.get_ylim()[1] for axi in axs]).max()



fig.text(0.005, 0.5, r"Log$_{2}$ Fold Change", rotation="vertical", va ="center", fontsize=16)
#fig.text(0.45, 0, "Phylum", fontsize=16)

#dummy_lines = []
#for p in phyla.index.tolist():
 #   l, = axs[0].plot([1],[1], "o", color = cd[p], label = p)
  #  dummy_lines.append(l)

#l, = axs[0].plot([1],[1], "o", color = "k", label = "unassigned")
#dummy_lines.append(l)

leg = fig.legend(dummy_lines, phyla.index.tolist() + ["unassigned"], ncol=1, numpoints=1, 
        loc=1, bbox_to_anchor=(0.84, 1.05), frameon = False, prop = {"size":12, "style":"italic"})

leg.set_title("Phylum")
ax.set_xlabel('Phylum')

# %%
fig.savefig("figs/l2fc_fig_SS.png", bbox_inches = "tight", dpi = 800)
FileLink("figs/l2fc_fig_SS.png")
# Out:
# /home/ashley/single_substrate/figs/l2fc_fig_SS.png

# %%
FDR = 0.10
df_resp = df_all[df_all["padj"]<=FDR]
df_resp.to_csv ("data/df_resp.csv")

# %%
#!head data/df_resp.csv

# %%
df = df_pivot

matplotlib.rcParams["axes.facecolor"] = "white"
matplotlib.rcParams["axes.edgecolor"] = "#151515"
matplotlib.rcParams["grid.color"] = "#F5F5F5"
matplotlib.rcParams["grid.alpha"] = "0.75"

thresh = 0.75

fig = plt.figure()
fig.set_size_inches(12,7)

gs = gridspec.GridSpec(nrows = 2, ncols = 3, width_ratios=[0.3,0.15,0.3], 
                       left=0.05, right=0.95, bottom=0.05, top=0.95,
                       hspace=0.3, wspace=0.12)

N = len(phyla.index) + 1
treatment = ["13CCPS", "13CCSS"]
days = [30]
ncol = 1
nrow = 2
for j, d in zip(range(ncol), days):
    for i, t in zip(range(nrow), treatment):
        try:
            
            df_resp_day_treatment = df_resp[(df_resp["Day"]==d)&(df_resp["Treatment"]==t)]
            resp_IDs = df_resp_day_treatment.OTU
            
            ax = fig.add_subplot(gs[i,j])
            X = df.X + 0.45 * np.random.random(len(df.X))
            Y = df[(t,d)]
            points = ax.scatter(X,
                                Y, alpha = 0.75, c = df.phylum_color.tolist(), 
                                s = 20, linewidth=0.25, edgecolor = "#505050")
            
            resp = ax.scatter(X[X.index.isin(resp_IDs)], 
                              Y[Y.index.isin(resp_IDs)], 
                              color = "k", 
                              s = 20,
                              marker = "x",
                              linewidth=1)
            
            ax.axhline(thresh, color = "#151515")
            ax.set_title("%s %s"%(t, d))
        except KeyError:
            ax.set_visible(False)
            continue

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()            

for axi in axs:
    axi.set_xlim([xmin,xmax])

axHistX = fig.add_subplot(gs[0, 1])
axHistX.hist(df_all[df_all["Treatment"]=="13CCPS"]["log2FoldChange"].values, orientation="horizontal", 
             bins=25, fc = "#252525")
axHistX.axhline(thresh)
axHistX.set_yticklabels([])
axHistX.set_ylim([-3,4])

axHistY = fig.add_subplot(gs[1, 1])
axHistY.hist(df_all[df_all["Treatment"]=="13CCSS"]["log2FoldChange"].values, orientation="horizontal", 
             bins=25, fc = "#252525")
axHistY.axhline(thresh)

axs = fig.get_axes()
xmin = np.array([axi.get_xlim()[0] for axi in axs]).min()
xmax = np.array([axi.get_xlim()[1] for axi in axs]).max()
ymin = np.array([axi.get_ylim()[0] for axi in axs]).min()
ymax = np.array([axi.get_ylim()[1] for axi in axs]).max()

for i, axi in enumerate(axs):
    if i == 10:
        axi.set_xticklabels([])
        axi.set_ylim([ymin,ymax])
        continue
    elif i == 11:
        axi.set_ylim([ymin,ymax])
        axi.set_xlabel("counts")
        continue
    axi.set_ylim([ymin,ymax])
  
for axi in axs[3:]:
    axi.set_yticklabels([])

axs[-1].set_xticklabels(axs[-1].get_xticks(), rotation = -90, size = 8)
axs[-2].set_xlim(axs[-1].get_xlim())

fig.text(0.005, 0.5, r"Log$_{2}$ Fold Change", rotation="vertical", va ="center", fontsize=16)
#fig.text(0.45, 0, "Phylum", fontsize=16)

#dummy_lines = []
#for p in phyla.index.tolist():
   # l, = axs[0].plot([1],[1], "o", color = cd[p], label = p)
    #dummy_lines.append(l)

#dummy_lines = []
#for p in phyla.index.tolist():
    #l, = axs[0].plot([1],[1], "o", color = cd[p], label = p)
   # dummy_lines.append(l)

leg = fig.legend(dummy_lines, phyla.index.tolist(), "upper left", ncol=1, numpoints=1, 
           bbox_to_anchor=(0.60, 1.04), frameon = False, prop = {"size":12, "style":"italic"})

leg.set_title("Phylum")
ax.set_xlabel('Phylum')

# %%
fig.savefig("figs/l2fc_fig_SS_pVal.png", bbox_inches = "tight", dpi = 500)
FileLink("figs/l2fc_fig_SS_pVal.png")
